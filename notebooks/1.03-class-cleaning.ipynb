# %%
import pandas as pd
from cdc_ml.datasets.customer_class.customer_class import clean_df
from cdc_ml.config import CUSTOMER_CLASS_RAW
# Out:
# 2026-05-08 18:19:18.652 | INFO     | cdc_ml.config:<module>:12 - PROJ_ROOT path is: C:\Users\zhiju\Desktop\cdc_ml

# %%
df_class = pd.read_csv(CUSTOMER_CLASS_RAW)
df = clean_df(df_class)

# %%
df.tail()
# Out:
#    username class_type  is_one_team
# 65  ranjith          3            0
# 66      fir         3a            0
# 67  afellow         3a            0
# 68    isyaf         3a            0
# 69      max         3a            1

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 70 entries, 0 to 69
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   username     70 non-null     str
#  1   class_type   70 non-null     str
#  2   is_one_team  70 non-null     int64
# dtypes: int64(1), str(2)
# memory usage: 2.4 KB
