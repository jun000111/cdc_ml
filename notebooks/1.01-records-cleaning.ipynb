# %%
import pandas as pd
from pandas import Series
import re
from cdc_ml.config import RAW_DATA_DIR
from cdc_ml.dataset.records.records import clean_df

# %%
df = pd.read_csv(RAW_DATA_DIR/"records.csv")

# %%
df.head()
# Out:
#    id  ...                        created_at
# 0   1  ...  2025-08-05 16:05:19.533091+00:00
# 1  19  ...  2025-08-08 15:14:18.789640+00:00
# 2  20  ...  2025-08-10 07:39:16.993798+00:00
# 3  21  ...  2025-08-10 17:09:18.087665+00:00
# 4  22  ...  2025-08-10 17:09:40.512199+00:00
#
# [5 rows x 4 columns]

# %%
df = clean_df(df)
# Out:
# 2026-05-04 12:27:51.643 | INFO     | cdc_ml.dataset.records.records:clean_df:99 - Pre-Clean: 432 rows
# 2026-05-04 12:27:51.659 | INFO     | cdc_ml.dataset.records.records:clean_df:106 - Main customers only: 279 row
# 2026-05-04 12:27:51.664 | INFO     | cdc_ml.dataset.records.records:clean_df:110 - Post-Clean: 223 rows

# %%
df.head()
# Out:
#     id username  ...          lesson_timestamp                booking_timestamp
# 42  60  ajithak  ... 2025-08-28 18:50:00+08:00 2025-08-21 09:24:06.300383+08:00
# 43  61  ajithak  ... 2025-08-28 20:40:00+08:00 2025-08-21 09:24:16.048708+08:00
# 44  62   addity  ... 2025-09-21 14:35:00+08:00 2025-08-23 00:57:26.576198+08:00
# 45  63    bryan  ... 2025-08-28 20:40:00+08:00 2025-08-25 12:06:06.539664+08:00
# 55  73    bryan  ... 2025-08-31 12:45:00+08:00 2025-08-26 12:50:24.317931+08:00
#
# [5 rows x 6 columns]
