# %%
import pandas as pd
from cdc_ml.datasets.customer_class.customer_class import generate_class_df
from cdc_ml.config import RAW_CLASS_CSV,INTERIM_COMPLETE_RECORDS_PARQUET
# Out:
# 2026-05-06 23:10:59.893 | INFO     | cdc_ml.config:<module>:12 - PROJ_ROOT path is: C:\Users\zhiju\Desktop\cdc_ml

# %%
df_class = pd.read_csv(RAW_CLASS_CSV)
df_records = pd.read_parquet(INTERIM_COMPLETE_RECORDS_PARQUET)
df = generate_class_df(df_class,df_records)

# %%
df
# Out:
#    username class_type  is_one_team
# 0      matt         3a            1
# 1      srpr          3            0
# 2     carol         3a            0
# 3     bhara          3            0
# 4     bhara          3            0
# 5         d          3            0
# 6       nur         3a            0
# 7     natar          3            1
# 8       joy          3            0
# 9      ryan          3            1
# 10     phuc         3a            1
# 11  gohguan         3a            0
# 12    anaya          3            0
# 13   addity         3a            1
# 14   poopie         3a            0
# 15  pakning         3a            1
# 16    apple          3            0
# 17       np         3a            0
# 18      jun         3a            0
# 19   tomato         3a            1
# 20    faith         3a            1
# 21    anmol         3a            0
# 22       jy          3            0
# 23   aswath         3a            0
# 24      kim         3a            0
# ...
