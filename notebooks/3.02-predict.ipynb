# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from cdc_ml.plots import production_visualization

# %%
production_visualization("matt",8,15)
# Out:
# 2026-06-09 15:04:43.386 | INFO     | cdc_ml.datasets.cycle.cycle:clean_df:56 - Pre cleaning:9 rows x 9 columns
