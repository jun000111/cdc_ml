# %%
import pandas as pd
from cdc_ml.datasets.poll.poll import generate_df
from cdc_ml.config import BOOKING_CYCLES_PROCESSED,RECORDS_PROCESSED
# Out:
# 2026-05-31 20:12:42.140 | INFO     | cdc_ml.config:<module>:12 - PROJ_ROOT path is: C:\Users\zhiju\Desktop\cdc_ml

# %%
df_cycle = pd.read_parquet(BOOKING_CYCLES_PROCESSED)
df_records = pd.read_parquet(RECORDS_PROCESSED)

# %%
df = generate_df(df_cycle,df_records)
# Out:
# 2026-05-31 20:12:43.038 | INFO     | cdc_ml.datasets.poll.poll:validate_booking_records:55 - All booking records are validated against booking cycle...

# %%
df.head()
# Out:
#    id  cycle_id username               cycle_start                 cycle_end  \
# 0   0         0  ajithak 2025-08-19 09:15:00+08:00 2025-08-21 11:00:00+08:00
# 1   1         0  ajithak 2025-08-19 09:15:00+08:00 2025-08-21 11:00:00+08:00
# 2   2         0  ajithak 2025-08-19 09:15:00+08:00 2025-08-21 11:00:00+08:00
# 3   3         0  ajithak 2025-08-19 09:15:00+08:00 2025-08-21 11:00:00+08:00
# 4   4         0  ajithak 2025-08-19 09:15:00+08:00 2025-08-21 11:00:00+08:00
#
#                  polling_at  has_booking  cycle_start_month  cycle_start_day  \
# 0 2025-08-19 09:00:00+08:00        False                  8               19
# 1 2025-08-19 10:00:00+08:00        False                  8               19
# 2 2025-08-19 11:00:00+08:00        False                  8               19
# 3 2025-08-19 12:00:00+08:00        False                  8               19
# 4 2025-08-19 13:00:00+08:00        False                  8               19
#
#    cycle_start_dow  cycle_start_hour  polling_month  polling_day  polling_dow  \
# 0                1                 9              8           19            1
# 1                1                 9              8           19            1
# 2                1                 9              8           19            1
# 3                1                 9              8           19            1
# 4                1                 9              8           19            1
#
#    polling_hour  hours_into_cycle
# 0             9             -0.25
# 1            10              0.75
# 2            11              1.75
# 3            12              2.75
# 4            13              3.75

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 32492 entries, 0 to 32491
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 32492 non-null  int64
#  1   cycle_id           32492 non-null  int64
#  2   username           32492 non-null  str
#  3   cycle_start        32492 non-null  datetime64[us, Asia/Singapore]
#  4   cycle_end          32492 non-null  datetime64[us, Asia/Singapore]
#  5   polling_at         32492 non-null  datetime64[us, Asia/Singapore]
#  6   has_booking        32492 non-null  bool
#  7   cycle_start_month  32492 non-null  int32
#  8   cycle_start_day    32492 non-null  int32
#  9   cycle_start_dow    32492 non-null  int32
#  10  cycle_start_hour   32492 non-null  int32
#  11  polling_month      32492 non-null  int32
#  12  polling_day        32492 non-null  int32
#  13  polling_dow        32492 non-null  int32
#  14  polling_hour       32492 non-null  int32
#  15  hours_into_cycle   32492 non-null  float64
# dtypes: bool(1), datetime64[us, Asia/Singapore](3), float64(1), int32(8), int64(2), str(1)
# memory usage: 2.9 MB
